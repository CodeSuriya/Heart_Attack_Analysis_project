# %%
import pandas as pd

# %%
import numpy as np

# %%
global_df = pd.read_csv("C:/Users/jsuri/Downloads/Datasets/Global_dataset.csv")

# %%
global_df
# Out:
#               ID Age_Group  Gender        Ethnicity  Smoking_Status  \
# 0              1     Youth  Female  Native American  Current Smoker
# 1              2     Adult  Female  Native American      Non-smoker
# 2              3     Adult    Male  Native American   Former Smoker
# 3              4     Adult  Female            Black      Non-smoker
# 4              5     Youth    Male            White      Non-smoker
# ...          ...       ...     ...              ...             ...
# 4999995  4999996     Adult    Male            Asian   Former Smoker
# 4999996  4999997     Youth    Male         Hispanic  Current Smoker
# 4999997  4999998     Adult  Female            White   Former Smoker
# 4999998  4999999     Adult    Male            White      Non-smoker
# 4999999  5000000     Youth    Male         Hispanic      Non-smoker
#
#         Alcohol_Consumption Diet_Quality  Cholesterol_Level  Blood_Pressure  \
# ...

# %%
global_df.head()
# Out:
#    ID Age_Group  Gender        Ethnicity  Smoking_Status Alcohol_Consumption  \
# 0   1     Youth  Female  Native American  Current Smoker            Moderate
# 1   2     Adult  Female  Native American      Non-smoker            Moderate
# 2   3     Adult    Male  Native American   Former Smoker            Moderate
# 3   4     Adult  Female            Black      Non-smoker            Moderate
# 4   5     Youth    Male            White      Non-smoker            Moderate
#
#   Diet_Quality  Cholesterol_Level  Blood_Pressure   BMI  Physical_Activity  \
# 0      Average                219             130  24.0                149
# 1      Average                151             122  35.6                199
# 2      Average                141             155  22.3                 98
# 3      Average                220             173  29.8                 24
# 4      Average                233             140  30.9                 78
#
# ...

# %%
global_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000000 entries, 0 to 4999999
# Data columns (total 20 columns):
#  #   Column               Dtype
# ---  ------               -----
#  0   ID                   int64
#  1   Age_Group            object
#  2   Gender               object
#  3   Ethnicity            object
#  4   Smoking_Status       object
#  5   Alcohol_Consumption  object
#  6   Diet_Quality         object
#  7   Cholesterol_Level    int64
#  8   Blood_Pressure       int64
#  9   BMI                  float64
#  10  Physical_Activity    int64
#  11  Stress_Level         object
#  12  Family_History       int64
#  13  Diabetes             int64
#  14  Air_Quality_Index    object
#  15  Income_Level         object
#  16  Sleep_Hours          float64
#  17  Heart_Rate           int64
#  18  Medication_Status    int64
#  19  Heart_Attack         int64
# dtypes: float64(2), int64(9), object(9)
# memory usage: 762.9+ MB

# %%
global_df.isnull().sum()
# Out:
# ID                           0
# Age_Group                    0
# Gender                       0
# Ethnicity                    0
# Smoking_Status               0
# Alcohol_Consumption    1998915
# Diet_Quality                 0
# Cholesterol_Level            0
# Blood_Pressure               0
# BMI                          0
# Physical_Activity            0
# Stress_Level                 0
# Family_History               0
# Diabetes                     0
# Air_Quality_Index            0
# Income_Level                 0
# Sleep_Hours                  0
# Heart_Rate                   0
# Medication_Status            0
# Heart_Attack                 0
# dtype: int64

# %%
global_df['Age_Group'].value_counts()
# Out:
# Age_Group
# Adult    2999540
# Youth    2000460
# Name: count, dtype: int64

# %%
global_df['Gender'].value_counts()
# Out:
# Gender
# Female    2400992
# Male      2399236
# Other      199772
# Name: count, dtype: int64

# %%
global_df['Ethnicity'].value_counts()
# Out:
# Ethnicity
# Black              1001528
# Native American    1000414
# White              1000228
# Asian               999220
# Hispanic            998610
# Name: count, dtype: int64

# %%
global_df.rename(columns={'Ethnicity':'Region_Category'},inplace = True)

# %%
global_df.head()
# Out:
#    ID Age_Group  Gender  Region_Category  Smoking_Status Alcohol_Consumption  \
# 0   1     Youth  Female  Native American  Current Smoker            Moderate
# 1   2     Adult  Female  Native American      Non-smoker            Moderate
# 2   3     Adult    Male  Native American   Former Smoker            Moderate
# 3   4     Adult  Female            Black      Non-smoker            Moderate
# 4   5     Youth    Male            White      Non-smoker            Moderate
#
#   Diet_Quality  Cholesterol_Level  Blood_Pressure   BMI  Physical_Activity  \
# 0      Average                219             130  24.0                149
# 1      Average                151             122  35.6                199
# 2      Average                141             155  22.3                 98
# 3      Average                220             173  29.8                 24
# 4      Average                233             140  30.9                 78
#
# ...

# %%
category_mapping={
'Asian' : 'Asia',
'Black' : 'Africa',
'Native American': 'North America',
'White': 'Europe',
'Hispanic':'South America'
    
}

# %%
global_df['Region_Category']= global_df['Region_Category'].replace(category_mapping)

# %%
global_df['Region_Category'].value_counts()
# Out:
# Region_Category
# Africa           1001528
# North America    1000414
# Europe           1000228
# Asia              999220
# South America     998610
# Name: count, dtype: int64

# %%
global_df.head()
# Out:
#    ID Age_Group  Gender Region_Category  Smoking_Status Alcohol_Consumption  \
# 0   1     Youth  Female   North America  Current Smoker            Moderate
# 1   2     Adult  Female   North America      Non-smoker            Moderate
# 2   3     Adult    Male   North America   Former Smoker            Moderate
# 3   4     Adult  Female          Africa      Non-smoker            Moderate
# 4   5     Youth    Male          Europe      Non-smoker            Moderate
#
#   Diet_Quality  Cholesterol_Level  Blood_Pressure   BMI  Physical_Activity  \
# 0      Average                219             130  24.0                149
# 1      Average                151             122  35.6                199
# 2      Average                141             155  22.3                 98
# 3      Average                220             173  29.8                 24
# 4      Average                233             140  30.9                 78
#
# ...

# %%
global_df['Smoking_Status'].value_counts()
# Out:
# Smoking_Status
# Non-smoker        3001619
# Former Smoker     1248260
# Current Smoker     750121
# Name: count, dtype: int64

# %%
global_df['Alcohol_Consumption'].value_counts()
# Out:
# Alcohol_Consumption
# Moderate    2501560
# High         499525
# Name: count, dtype: int64

# %%
global_df['Alcohol_Consumption'].isnull().sum()
# Out:
# 1998915

# %%
global_df['Alcohol_Consumption'].notnull().sum()
# Out:
# 3001085

# %%
moderate_ratio = global_df['Alcohol_Consumption'].value_counts(normalize = True)['Moderate']

# %%
moderate_ratio
# Out:
# 0.8335518654086772

# %%
moderate_percentage = moderate_ratio *100

# %%
moderate_percentage
# Out:
# 83.35518654086772

# %%
high_ratio = global_df['Alcohol_Consumption'].value_counts(normalize = True)['High']

# %%
high_ratio
# Out:
# 0.1664481345913228

# %%
high_percentage = high_ratio * 100

# %%
high_percentage
# Out:
# 16.64481345913228

# %%
np.random.seed(42)

global_df.loc[global_df['Alcohol_Consumption'].isnull(),'Alcohol_Consumption']=np.random.choice(
    ['Moderate','High'],
    size = global_df['Alcohol_Consumption'].isnull().sum(),
    p = [moderate_ratio , high_ratio]
)

# %%
global_df['Alcohol_Consumption'].value_counts()
# Out:
# Alcohol_Consumption
# Moderate    4168591
# High         831409
# Name: count, dtype: int64

# %%
global_df.head()
# Out:
#    ID Age_Group  Gender Region_Category  Smoking_Status Alcohol_Consumption  \
# 0   1     Youth  Female   North America  Current Smoker            Moderate
# 1   2     Adult  Female   North America      Non-smoker            Moderate
# 2   3     Adult    Male   North America   Former Smoker            Moderate
# 3   4     Adult  Female          Africa      Non-smoker            Moderate
# 4   5     Youth    Male          Europe      Non-smoker            Moderate
#
#   Diet_Quality  Cholesterol_Level  Blood_Pressure   BMI  Physical_Activity  \
# 0      Average                219             130  24.0                149
# 1      Average                151             122  35.6                199
# 2      Average                141             155  22.3                 98
# 3      Average                220             173  29.8                 24
# 4      Average                233             140  30.9                 78
#
# ...

# %%
global_df['Alcohol_Consumption'].isnull().sum()
# Out:
# 0

# %%
global_df['Diet_Quality'].isnull().sum()
# Out:
# 0

# %%
global_df['Diet_Quality'].value_counts()
# Out:
# Diet_Quality
# Average      2497954
# Poor         1500628
# Excellent    1001418
# Name: count, dtype: int64

# %%
global_df['Cholesterol_Level'].isnull().sum()
# Out:
# 0

# %%
global_df['Blood_Pressure'].isnull().sum()
# Out:
# 0

# %%
global_df['BMI'].isnull().sum()
# Out:
# 0

# %%
global_df['Physical_Activity'].isnull().sum()
# Out:
# 0

# %%
global_df['Stress_Level'].isnull().sum()
# Out:
# 0

# %%
global_df['Family_History'].isnull().sum()
# Out:
# 0

# %%
global_df.drop(['Family_History'],axis = 1, inplace  = True)

# %%
global_df.head()
# Out:
#    ID Age_Group  Gender Region_Category  Smoking_Status Alcohol_Consumption  \
# 0   1     Youth  Female   North America  Current Smoker            Moderate
# 1   2     Adult  Female   North America      Non-smoker            Moderate
# 2   3     Adult    Male   North America   Former Smoker            Moderate
# 3   4     Adult  Female          Africa      Non-smoker            Moderate
# 4   5     Youth    Male          Europe      Non-smoker            Moderate
#
#   Diet_Quality  Cholesterol_Level  Blood_Pressure   BMI  Physical_Activity  \
# 0      Average                219             130  24.0                149
# 1      Average                151             122  35.6                199
# 2      Average                141             155  22.3                 98
# 3      Average                220             173  29.8                 24
# 4      Average                233             140  30.9                 78
#
# ...

# %%
global_df['Diabetes'] = global_df['Diabetes'].replace({0: 'No Diabetes', 1: 'Has Diabetes'})

# %%
global_df.head()
# Out:
#    ID Age_Group  Gender Region_Category  Smoking_Status Alcohol_Consumption  \
# 0   1     Youth  Female   North America  Current Smoker            Moderate
# 1   2     Adult  Female   North America      Non-smoker            Moderate
# 2   3     Adult    Male   North America   Former Smoker            Moderate
# 3   4     Adult  Female          Africa      Non-smoker            Moderate
# 4   5     Youth    Male          Europe      Non-smoker            Moderate
#
#   Diet_Quality  Cholesterol_Level  Blood_Pressure   BMI  Physical_Activity  \
# 0      Average                219             130  24.0                149
# 1      Average                151             122  35.6                199
# 2      Average                141             155  22.3                 98
# 3      Average                220             173  29.8                 24
# 4      Average                233             140  30.9                 78
#
# ...

# %%
global_df['Diabetes'].value_counts()
# Out:
# Diabetes
# No Diabetes     3999012
# Has Diabetes    1000988
# Name: count, dtype: int64

# %%
global_df['Air_Quality_Index'].isnull().sum()
# Out:
# 0

# %%
global_df['Income_Level'].isnull().sum()
# Out:
# 0

# %%
global_df['Sleep_Hours'].isnull().sum()
# Out:
# 0

# %%
global_df['Heart_Rate'].isnull().sum()
# Out:
# 0

# %%
global_df['Medication_Status'].isnull().sum()
# Out:
# 0

# %%
global_df['Heart_Attack'].isnull().sum()
# Out:
# 0

# %%
global_df['Heart_Attack'].value_counts()
# Out:
# Heart_Attack
# 0    4499720
# 1     500280
# Name: count, dtype: int64

# %%
global_df['Medication_Status'].value_counts()
# Out:
# Medication_Status
# 0    4250600
# 1     749400
# Name: count, dtype: int64

# %%
global_df['Medication_Status'] = global_df['Medication_Status'].replace({
    0: 'Not on Medication',
    1: 'On Medication'
})

# %%
global_df['Medication_Status'].value_counts()
# Out:
# Medication_Status
# Not on Medication    4250600
# On Medication         749400
# Name: count, dtype: int64

# %%
global_df['Heart_Attack'] = global_df['Heart_Attack'].replace({
    0: 'No Heart Attack',
    1: 'Heart Attack Occurred'
})

# %%
global_df['Heart_Attack'].value_counts()
# Out:
# Heart_Attack
# No Heart Attack          4499720
# Heart Attack Occurred     500280
# Name: count, dtype: int64

# %%
global_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000000 entries, 0 to 4999999
# Data columns (total 19 columns):
#  #   Column               Dtype
# ---  ------               -----
#  0   ID                   int64
#  1   Age_Group            object
#  2   Gender               object
#  3   Region_Category      object
#  4   Smoking_Status       object
#  5   Alcohol_Consumption  object
#  6   Diet_Quality         object
#  7   Cholesterol_Level    int64
#  8   Blood_Pressure       int64
#  9   BMI                  float64
#  10  Physical_Activity    int64
#  11  Stress_Level         object
#  12  Diabetes             object
#  13  Air_Quality_Index    object
#  14  Income_Level         object
#  15  Sleep_Hours          float64
#  16  Heart_Rate           int64
#  17  Medication_Status    object
#  18  Heart_Attack         object
# dtypes: float64(2), int64(5), object(12)
# memory usage: 724.8+ MB

# %%
global_df
# Out:
#               ID Age_Group  Gender Region_Category  Smoking_Status  \
# 0              1     Youth  Female   North America  Current Smoker
# 1              2     Adult  Female   North America      Non-smoker
# 2              3     Adult    Male   North America   Former Smoker
# 3              4     Adult  Female          Africa      Non-smoker
# 4              5     Youth    Male          Europe      Non-smoker
# ...          ...       ...     ...             ...             ...
# 4999995  4999996     Adult    Male            Asia   Former Smoker
# 4999996  4999997     Youth    Male   South America  Current Smoker
# 4999997  4999998     Adult  Female          Europe   Former Smoker
# 4999998  4999999     Adult    Male          Europe      Non-smoker
# 4999999  5000000     Youth    Male   South America      Non-smoker
#
#         Alcohol_Consumption Diet_Quality  Cholesterol_Level  Blood_Pressure  \
# 0                  Moderate      Average                219             130
# ...

# %%
global_df.to_csv('cleaned_global_dataset.csv', index=False)

# %%
loaded_df = pd.read_csv('cleaned_global_dataset.csv')

# %%
loaded_df
# Out:
#               ID Age_Group  Gender Region_Category  Smoking_Status  \
# 0              1     Youth  Female   North America  Current Smoker
# 1              2     Adult  Female   North America      Non-smoker
# 2              3     Adult    Male   North America   Former Smoker
# 3              4     Adult  Female          Africa      Non-smoker
# 4              5     Youth    Male          Europe      Non-smoker
# ...          ...       ...     ...             ...             ...
# 4999995  4999996     Adult    Male            Asia   Former Smoker
# 4999996  4999997     Youth    Male   South America  Current Smoker
# 4999997  4999998     Adult  Female          Europe   Former Smoker
# 4999998  4999999     Adult    Male          Europe      Non-smoker
# 4999999  5000000     Youth    Male   South America      Non-smoker
#
#         Alcohol_Consumption Diet_Quality  Cholesterol_Level  Blood_Pressure  \
# 0                  Moderate      Average                219             130
# ...
