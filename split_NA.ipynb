# %%
import pandas as pd

# %%
na_df = pd.read_csv("C:/Users/jsuri/Downloads/H_A/north_america_dataset.csv")

# %%
# Get total rows and calculate split size
total_rows = len(na_df)  # 1,000,414 rows
split_size = total_rows // 2  # 500,207 rows per file

# %%
# Split into two parts
na_df_part1 = na_df.iloc[:split_size]  # First 500,207 rows
na_df_part2 = na_df.iloc[split_size:]  # Remaining 500,207 rows

# %%
na_df_part1.head()
# Out:
#    ID Age_Group  Gender Region_Category  Smoking_Status Alcohol_Consumption  \
# 0   1     Youth  Female   United States  Current Smoker            Moderate
# 1   2     Adult  Female   United States      Non-smoker            Moderate
# 2   3     Adult    Male   United States   Former Smoker            Moderate
# 3   4     Youth   Other   United States   Former Smoker            Moderate
# 4   5     Youth    Male   United States      Non-smoker            Moderate
#
#   Diet_Quality  Cholesterol_Level  Blood_Pressure   BMI Physical_Activity  \
# 0      Average                219             130  24.0          Moderate
# 1      Average                151             122  35.6              Good
# 2      Average                141             155  22.3          Moderate
# 3      Average                122              98  27.0          Moderate
# 4         Poor                251             174  37.6              Good
#
# ...

# %%
na_df_part1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500207 entries, 0 to 500206
# Data columns (total 19 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   ID                   500207 non-null  int64
#  1   Age_Group            500207 non-null  object
#  2   Gender               500207 non-null  object
#  3   Region_Category      500207 non-null  object
#  4   Smoking_Status       500207 non-null  object
#  5   Alcohol_Consumption  500207 non-null  object
#  6   Diet_Quality         500207 non-null  object
#  7   Cholesterol_Level    500207 non-null  int64
#  8   Blood_Pressure       500207 non-null  int64
#  9   BMI                  500207 non-null  float64
#  10  Physical_Activity    500207 non-null  object
#  11  Stress_Level         500207 non-null  object
#  12  Diabetes             500207 non-null  object
#  13  Air_Quality_Index    500207 non-null  object
#  14  Income_Level         500207 non-null  object
# ...

# %%
na_df_part2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500207 entries, 500207 to 1000413
# Data columns (total 19 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   ID                   500207 non-null  int64
#  1   Age_Group            500207 non-null  object
#  2   Gender               500207 non-null  object
#  3   Region_Category      500207 non-null  object
#  4   Smoking_Status       500207 non-null  object
#  5   Alcohol_Consumption  500207 non-null  object
#  6   Diet_Quality         500207 non-null  object
#  7   Cholesterol_Level    500207 non-null  int64
#  8   Blood_Pressure       500207 non-null  int64
#  9   BMI                  500207 non-null  float64
#  10  Physical_Activity    500207 non-null  object
#  11  Stress_Level         500207 non-null  object
#  12  Diabetes             500207 non-null  object
#  13  Air_Quality_Index    500207 non-null  object
# ...

# %%
na_df_part2.head()
# Out:
#             ID Age_Group  Gender Region_Category  Smoking_Status  \
# 500207  500208     Adult  Female          Canada      Non-smoker
# 500208  500209     Adult    Male   United States   Former Smoker
# 500209  500210     Adult    Male   United States  Current Smoker
# 500210  500211     Adult    Male   United States      Non-smoker
# 500211  500212     Youth  Female   United States      Non-smoker
#
#        Alcohol_Consumption Diet_Quality  Cholesterol_Level  Blood_Pressure  \
# 500207            Moderate         Poor                159              91
# 500208            Moderate         Poor                144             144
# 500209            Moderate      Average                289             172
# 500210            Moderate    Excellent                151             157
# 500211            Moderate      Average                152             149
#
#          BMI Physical_Activity Stress_Level     Diabetes Air_Quality_Index  \
# ...

# %%
na_df_part1.to_csv("C:/Users/jsuri/Downloads/H_A/north_america_part_1.csv", index=False)

# %%
na_df_part2.to_csv("C:/Users/jsuri/Downloads/H_A/north_america_part_2.csv", index=False)
